# %%
set1 = { "One", "Two", "Three", "One", (1,2,3)}
set1
# Out:
# {(1, 2, 3), 'One', 'Three', 'Two'}

# %%
Dict = {"key1": 1, "key2": "2", "key3": [3, 3, 3], "key4": (4, 4, 4), ('key5'): 5, (0, 1): 6}
Dict
# Out:
# {'key1': 1,
#  'key2': '2',
#  'key3': [3, 3, 3],
#  'key4': (4, 4, 4),
#  'key5': 5,
#  (0, 1): 6}

# %%
dict_set = set(Dict)
dict_set
# Out:
# {(0, 1), 'key1', 'key2', 'key3', 'key4', 'key5'}

# %%
ListData = [ "One", "Two", "Three", "One", (1,2,3)]
ListDataSet = set(ListData)
ListDataSet
# Out:
# {(1, 2, 3), 'One', 'Three', 'Two'}

# %%
ListDataSet.add("one1")
ListDataSet
# Out:
# {(1, 2, 3), 'One', 'Three', 'Two', 'one', 'one1'}

# %%
ListDataSet.remove('one1')
ListDataSet
# Out:
# {(1, 2, 3), 'One', 'Three', 'Two', 'one'}

# %%
'one1' in ListDataSet
# Out:
# False

# %%
A = { 1,2,3 }
B = {3,4,5}
C = A & B
C
# Out:
# {3}

# %%
D = A.union(B)
D
# Out:
# {1, 2, 3, 4, 5}

# %%
A = { 1,2,3 }
B = {1,2}
C = B.issubset(A)
C
# Out:
# True

# %%
A, B , C, A.union(B), 1 in A, 3 in B
# Out:
# ({1, 2, 3}, {1, 2}, True, {1, 2, 3}, True, False)

# %%
A.difference(B)
# Out:
# {3}

# %%
B.difference(A)
# Out:
# set()

# %%
A.intersection(B)
# Out:
# {1, 2}

# %%
A.issuperset(B)
# Out:
# True

# %%
A = { 1,2,3, 5 }
B = {1,2,3, 5, 6}
B.issuperset(A)
# Out:
# True
