# %%
feedbackString = r"Efficiency:  Your process for handling client inquiries is so efficient; youre resolving issues much faster, freeing up the team for complex tasks. Quality:  The attention to detail in your testing caught a critical bug before launch, ensuring a smooth release for our users. Initiative:  Building that new reporting dashboard was a huge win—its saved us hours and gives leadership great visibility. Collaboration:  Thanks for keeping everyone updated on the project status; it made coordination seamless and kept us on track "

# %%
feedbackString
# Out:
# 'Efficiency:  Your process for handling client inquiries is so efficient; youre resolving issues much faster, freeing up the team for complex tasks. Quality:  The attention to detail in your testing caught a critical bug before launch, ensuring a smooth release for our users. Initiative:  Building that new reporting dashboard was a huge win—its saved us hours and gives leadership great visibility. Collaboration:  Thanks for keeping everyone updated on the project status; it made coordination seamless and kept us on track '

# %%
feedbackString.lower()
# Out:
# 'efficiency:  your process for handling client inquiries is so efficient; youre resolving issues much faster, freeing up the team for complex tasks. quality:  the attention to detail in your testing caught a critical bug before launch, ensuring a smooth release for our users. initiative:  building that new reporting dashboard was a huge win—its saved us hours and gives leadership great visibility. collaboration:  thanks for keeping everyone updated on the project status; it made coordination seamless and kept us on track '

# %%
feedbackString.replace(":"," ").replace(";"," ").replace("'"," ").replace("\""," ").replace("?"," ").replace(" ","")
# Out:
# 'EfficiencyYourprocessforhandlingclientinquiriesissoefficientyoureresolvingissuesmuchfaster,freeinguptheteamforcomplextasks.QualityTheattentiontodetailinyourtestingcaughtacriticalbugbeforelaunch,ensuringasmoothreleaseforourusers.InitiativeBuildingthatnewreportingdashboardwasahugewin—itssavedushoursandgivesleadershipgreatvisibility.CollaborationThanksforkeepingeveryoneupdatedontheprojectstatusitmadecoordinationseamlessandkeptusontrack'

# %%
feedbackStringList = feedbackString.split(" ")
feedbackStringList
# Out:
# ['Efficiency:',
#  '',
#  'Your',
#  'process',
#  'for',
#  'handling',
#  'client',
#  'inquiries',
#  'is',
#  'so',
#  'efficient;',
#  'youre',
#  'resolving',
#  'issues',
#  'much',
#  'faster,',
#  'freeing',
#  'up',
#  'the',
#  'team',
#  'for',
#  'complex',
#  'tasks.',
#  'Quality:',
#  '',
#  'The',
#  'attention',
#  'to',
#  'detail',
#  'in',
#  'your',
#  'testing',
#  'caught',
#  'a',
#  'critical',
#  'bug',
#  'before',
#  'launch,',
#  'ensuring',
#  'a',
#  'smooth',
#  'release',
#  'for',
#  'our',
#  'users.',
#  'Initiative:',
#  '',
#  'Building',
#  'that',
#  'new',
#  'reporting',
#  'dashboard',
#  'was',
#  'a',
#  'huge',
#  'win—its',
#  'saved',
#  'us',
#  'hours',
#  'and',
#  'gives',
#  'leadership',
#  'great',
#  'visibility.',
#  'Collaboration:',
#  '',
#  'Thanks',
#  'for',
#  'keeping',
#  'everyone',
#  'updated',
#  'on',
#  'the',
#  'project',
#  'status;',
#  'it',
#  'made',
#  'coordination',
#  'seamless',
#  'and',
#  'kept',
# ...

# %%
freqMap = {}
for word in set(feedbackStringList):
    freqMap[word] = feedbackStringList.count(word)

# %%
freqMap
# Out:
# {'': 5,
#  'reporting': 1,
#  'much': 1,
#  'freeing': 1,
#  'Your': 1,
#  'complex': 1,
#  'The': 1,
#  'huge': 1,
#  'win—its': 1,
#  'inquiries': 1,
#  'Building': 1,
#  'everyone': 1,
#  'us': 2,
#  'on': 2,
#  'detail': 1,
#  'faster,': 1,
#  'made': 1,
#  'team': 1,
#  'attention': 1,
#  'so': 1,
#  'Efficiency:': 1,
#  'updated': 1,
#  'keeping': 1,
#  'client': 1,
#  'the': 2,
#  'resolving': 1,
#  'great': 1,
#  'Collaboration:': 1,
#  'dashboard': 1,
#  'users.': 1,
#  'bug': 1,
#  'for': 4,
#  'leadership': 1,
#  'efficient;': 1,
#  'before': 1,
#  'gives': 1,
#  'critical': 1,
#  'your': 1,
#  'our': 1,
#  'visibility.': 1,
#  'project': 1,
#  'ensuring': 1,
#  'that': 1,
#  'and': 2,
#  'coordination': 1,
#  'kept': 1,
#  'hours': 1,
#  'track': 1,
#  'issues': 1,
#  'Quality:': 1,
#  'Initiative:': 1,
#  'Thanks': 1,
#  'seamless': 1,
#  'handling': 1,
#  'youre': 1,
#  'saved': 1,
#  'it': 1,
#  'new': 1,
#  'was': 1,
#  'caught': 1,
#  'is': 1,
#  'launch,': 1,
# ...

# %%
copyright_char = chr(169)
print(copyright_char)
# Out:
# ©
