# %%
age = 11
if age > 11:
    print("you can enter-True")
    print("asdasdasd")
elif age ==  11:
    print("--->{age}",age)
else:
    print("you cannot enter-False")
    print("-----------")
    print("++++++++++++")
print("Next code")
# Out:
# --->{age} 11
# Next code
