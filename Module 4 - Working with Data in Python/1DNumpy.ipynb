# %%
a = [1,"a",2,"two","3",4]
a
# Out:
# [1, 'a', 2, 'two', '3', 4]

# %%
a[2]
# Out:
# 2

# %%
import numpy as np
print(np.__version__)
a = np.array([0,1,2,3,4,5])
type(a)
# Out:
# 1.24.3
# numpy.ndarray

# %%
a.dtype
# Out:
# dtype('int32')

# %%
a.size
# Out:
# 6

# %%
a.ndim
# Out:
# 1

# %%
a.shape
# Out:
# (6,)

# %%
b=np.array([15.024,2.5,8.68,120.454])
b
# Out:
# array([ 15.024,   2.5  ,   8.68 , 120.454])

# %%
b.dtype
# Out:
# dtype('float64')

# %%
b.size
# Out:
# 4

# %%
b.shape
# Out:
# (4,)

# %%
type(b)
# Out:
# numpy.ndarray

# %%
b.ndim
# Out:
# 1

# %%
c=np.array([20,1,2,3,4])
c
# Out:
# array([20,  1,  2,  3,  4])

# %%
c[0]=100
c
# Out:
# array([100,   1,   2,   3,   4])

# %%
c[4]=0
c
# Out:
# array([100,   1,   2,   3,   0])

# %%
d=c[1:4]
d
# Out:
# array([1, 2, 3])

# %%
c[3:5]=300,400
c
# Out:
# array([100,   1,   2, 300, 400])

# %%
u = [0,1,2,3,4,5,6]
v = [1,0,5,6,7,8,8]
z = []
for n,m in zip(u,v):
    z.append(n+m)
z
# Out:
# [1, 1, 7, 9, 11, 13, 14]

# %%
u = np.array(u)
v = np.array(v)
z = u + v
z
# Out:
# array([ 1,  1,  7,  9, 11, 13, 14])

# %%
z = u - v
z
# Out:
# array([-1,  1, -3, -3, -3, -3, -2])

# %%
y = [1,2,3]
z=[]
for n in y:
    z.append(n*2)
z
# Out:
# [2, 4, 6]

# %%
y = np.array([1,2,3])
z = 2 * y
z
# Out:
# array([2, 4, 6])

# %%
u = [1,2,5,8,9,1,25,4]
v = [5,8,7,6,2,4,5,14]
z = []
for n,m in zip(u,v):
    z.append(n*m)
z
# Out:
# [5, 16, 35, 48, 18, 4, 125, 56]

# %%
u = np.array([1,2,5,8,9,1,25,4])
v = np.array([5,8,7,6,2,4,5,14])
z = u * v
print(z)
# Out:
# [  5  16  35  48  18   4 125  56]

# %%
#Dot Product
u = np.array([1,2,5,8,9,1,25,4])
v = np.array([5,8,7,6,2,4,5,14])
z = np.dot(u,v)
print(z)
# Out:
# 307

# %%
#brodcasting
u = np.array([1,2,5,8,9,1,25,4])
z = u+2
z
# Out:
# array([ 3,  4,  7, 10, 11,  3, 27,  6])

# %%
#Universal function 
u = np.array([1,2,5,8,9,1,25,4])
print(u.mean())
print(u.max())
# Out:
# 6.875
# 25

# %%
np.pi
# Out:
# 3.141592653589793

# %%
x = np.array([0,np.pi/2,np.pi])

# %%
np.sin(x)
# Out:
# array([0.0000000e+00, 1.0000000e+00, 1.2246468e-16])

# %%
np.linspace(-2,2,num=5)
# Out:
# array([-2., -1.,  0.,  1.,  2.])

# %%
np.linspace(-5,5,num=10)
# Out:
# array([-5.        , -3.88888889, -2.77777778, -1.66666667, -0.55555556,
#         0.55555556,  1.66666667,  2.77777778,  3.88888889,  5.        ])

# %%
import matplotlib.pyplot as plt 
x=np.linspace(0,1*np.pi,num=100)
y = np.tan(x)
# %matplotlib inline
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt 
x=np.linspace(0,2*np.pi,num=100)
y = np.sin(x)
# %matplotlib inline
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt 
x=np.linspace(0,5*np.pi,num=100)
y = np.cos(x)
# %matplotlib inline
plt.plot(x,y)

# %%
#We pass slice like this: [start:end].The element at end index is not being included in the output.
arr = np.array([1, 2, 3, 4, 5, 6, 7])
arr[1:4]
# Out:
# array([2, 3, 4])

# %%
arr[3:5] = 300, 400
arr
# Out:
# array([  1,   2,   3, 300, 400,   6,   7])

# %%
#We can also define the steps in slicing, like this: [start:end:step]
print(arr[1:5:2])
# Out:
# [  2 300]

# %%
import time 
import sys
import numpy as np 

import matplotlib.pyplot as plt


def Plotvec1(u, z, v):
    
    ax = plt.axes() # to generate the full window axes
    ax.arrow(0, 0, *u, head_width=0.05, color='r', head_length=0.1)# Add an arrow to the  U Axes with arrow head width 0.05, color red and arrow head length 0.1
    plt.text(*(u + 0.1), 'u')#Adds the text u to the Axes 
    
    ax.arrow(0, 0, *v, head_width=0.05, color='b', head_length=0.1)# Add an arrow to the  v Axes with arrow head width 0.05, color red and arrow head length 0.1
    plt.text(*(v + 0.1), 'v')#Adds the text v to the Axes 
    
    ax.arrow(0, 0, *z, head_width=0.05, head_length=0.1)
    plt.text(*(z + 0.1), 'z')#Adds the text z to the Axes 
    plt.ylim(-2, 2)#set the ylim to bottom(-2), top(2)
    plt.xlim(-2, 2)#set the xlim to left(-2), right(2)

# %%
u = np.array([1, 0])
v = np.array([0, 1])
z = np.add(u, v)
Plotvec1(u, z, v)
