# %%
file = open(r"C:\Users\v099452\Sample.txt","r")
print(file.name)
print(file)
print(file.readlines())
file.closed
file.close()
print(file.mode)
# Out:
# C:\Users\v099452\Sample.txt
# <_io.TextIOWrapper name='C:\\Users\\v099452\\Sample.txt' mode='r' encoding='cp1252'>
# ['111 as asd asd \\n asd asd as\n', '222 sdf sdf sd fsdf sd fsdf ']
# r

# %%
with open(r"C:\Users\v099452\Sample.txt","r") as file1:
    #file_data = file1.readlines();
    file_data = file1.readlines();
    print(file_data)
    file_data = file1.readline();
    print(file_data)
    file_data = file1.readline();
    print(file_data)    
print(file1.closed)
# Out:
# ['111 as asd asd \\n asd asd as\n', '222 sdf sdf sd fsdf sd fsdf ']
#
#
# True

# %%
with open(r"C:\Users\v099452\Sample.txt","r") as file1:
    file_data = file1.readlines();
    print(file_data)    
print(file1.closed)
# Out:
# ['111 as asd asd \\n asd asd as\n', '222 sdf sdf sd fsdf sd fsdf ']
# True

# %%
with open(r"C:\Users\v099452\Sample.txt","r") as file1:
    file_data = file1.readline();
    print(file_data)
    file_data = file1.readline();
    print(file_data)    
print(file1.closed)
# Out:
# 111 as asd asd \n asd asd as
#
# 222 sdf sdf sd fsdf sd fsdf
# True

# %%
with open(r"C:\Users\v099452\Sample.txt","r") as file1:
    file_data = file1.read();
    print(file_data)
print(file1.closed)
# Out:
# Line 1
# Line 2
# Line 3
# Line 4
# finished
#
# True

# %%
with open(r"C:\Users\v099452\Sample.txt",'r') as file1: 
    print(file1.closed)
    #print(file1.close())
    print(file1.readline())
    print(file1.readline())
    print(file1.readlines())
    print(file1.mode)
print(file1.closed)
# Out:
# False
# 111 as asd asd \n asd asd as
#
# 222 sdf sdf sd fsdf sd fsdf
# []
# r
# True

# %%
 with open(r"C:\Users\v099452\Sample.txt",'r') as file1:
     listData = file1.readlines()
     print(listData)

print(listData[0])
print(listData[0][5])
print(listData[0][0:5])
# Out:
# ['111 as asd asd \\n asd asd as\n', '222 sdf sdf sd fsdf sd fsdf ']
# 111 as asd asd \n asd asd as
#
# s
# 111 a

# %%
with open(r'C:\Users\v099452\Sample.txt','r') as file1:
    while True:
        line = file1.readline()
        if not line:
            break #Stop when there are no more lines to read
        print(line)
# Out:
# 111 as asd asd \n asd asd as
#
# 222 sdf sdf sd fsdf sd fsdf
#
# 333 sdf sdf sd fsdf sd fsdf
#
#
#
#
#
# 444 sdf sdf sd fsdf sd fsdf
#
# 555 sdf sdf sd fsdf sd fsdf

# %%
with open(r'C:\Users\v099452\Sample.txt','r') as file1:
    print(file1.read())
# Out:
# 111 as asd asd \n asd asd as
# 222 sdf sdf sd fsdf sd fsdf
# 333 sdf sdf sd fsdf sd fsdf
#
#
# 444 sdf sdf sd fsdf sd fsdf
# 555 sdf sdf sd fsdf sd fsdf

# %%
with open(r'C:\Users\v099452\Sample.txt','r') as file1:
    fileListData = file1.readlines()
    print(fileListData)

with open(r'C:\Users\v099452\Sample2.txt','w') as file2:
    for line in fileListData:
        file2.write(line)

with open(r'C:\Users\v099452\Sample2.txt','a') as file2:
    file2.write("\n this is from append")

with open(r'C:\Users\v099452\Sample2.txt','r') as file1:
    fileListData = file1.readlines()
    print(fileListData)
# Out:
# ['111 as asd asd \\n asd asd as\n', '222 sdf sdf sd fsdf sd fsdf \n', '333 sdf sdf sd fsdf sd fsdf \n', '\n', '\n', '444 sdf sdf sd fsdf sd fsdf\n', '555 sdf sdf sd fsdf sd fsdf ']
# ['111 as asd asd \\n asd asd as\n', '222 sdf sdf sd fsdf sd fsdf \n', '333 sdf sdf sd fsdf sd fsdf \n', '\n', '\n', '444 sdf sdf sd fsdf sd fsdf\n', '555 sdf sdf sd fsdf sd fsdf \n', ' this is from append']

# %%
with open(r'C:\Users\v099452\Sample.txt','r') as file1:
    with open(r'C:\Users\v099452\Sample2.txt','w') as file2:
        for line in file1.read():
            file2.write(line)

# %% [markdown]
# r+ : Reading and writing. Cannot truncate the file.
# w+ : Writing and reading. Truncates the file .
# a+ : Appending and Reading. Creates a new file, if none exists. You dont have to dwell on the specifics of each mode for this lab.

# %%
with open(r'C:\Users\v099452\Sample.txt','r+') as file1:
    print("Initial Location: {}".format(file1.tell()))
    file1.write("yyyy111111122222222222222")
    print("Initial Location: {}".format(file1.tell()))
# Out:
# Initial Location: 0
# Initial Location: 25

# %%
with open(r'C:\Users\v099452\Sample.txt','a+') as file1:
    print("Initial Location: {}".format(file1.tell()))
    file1.write("yyyy111111122222222222222")
    print("Initial Location: {}".format(file1.tell()))
# Out:
# Initial Location: 191
# Initial Location: 216

# %%
with open(r'C:\Users\v099452\Sample.txt','w+') as file1:
    print("Initial Location: {}".format(file1.tell()))
    file1.write("yyyy111111122222222222222")
    print("Initial Location: {}".format(file1.tell()))
# Out:
# Initial Location: 0
# Initial Location: 25

# %%
with open(r'C:\Users\v099452\Sample.txt','w') as file1:
    print(file1.read())
    print(file1.tell())
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[206], line 2
#       1 with open(r'C:\Users\v099452\Sample.txt','w') as file1:
# ----> 2     print(file1.read())
#       3     print(file1.tell())
#
# UnsupportedOperation: not readable

# %%
with open(r'C:\Users\v099452\Sample.txt','r+') as file1:
    print(file1.read())
    print(file1.tell())
# Out:
# 111 as asd asd \n asd asd as
# 222 sdf sdf sd fsdf sd fsdf
# 333 sdf sdf sd fsdf sd fsdf
#
#
# 444 sdf sdf sd fsdf sd fsdf
# 555 sdf sdf sd fsdf sd fsdf
# 151

# %%
with open(r'C:\Users\v099452\Sample.txt','a') as file1:
    print(file1.tell())
# Out:
# 151

# %%
with open(r'C:\Users\v099452\Sample.txt','w') as file1:
    print(file1.read())
    print(file1.tell())
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[250], line 2
#       1 with open(r'C:\Users\v099452\Sample.txt','w') as file1:
# ----> 2     print(file1.read())
#       3     print(file1.tell())
#
# UnsupportedOperation: not readable

# %%
with open(r'C:\Users\v099452\Sample.txt','a+') as  file1:
    print("Initial Location: {}".format(file1.tell()))
    data = file1.read()    
    if (not data):
        print('No data')
    else:
        print("--->"+data)
    print("current Location: {}".format(file1.tell()))
    file1.seek(0,0) # move 0 bytes from beginning.
    print("current Location: {}".format(file1.tell()))
    data = file1.read()
    if (not data):
        print('No data')
    else:
        print("--->"+data)
# Out:
# Initial Location: 163
# No data
# current Location: 163
# current Location: 0
# --->111 as asd asd \n asd asd as
#
# 222 sdf sdf sd fsdf sd fsdf
#
# 333 sdf sdf sd fsdf sd fsdf
#
#
#
#
#
# 444 sdf sdf sd fsdf sd fsdf
#
# 555 sdf sdf sd fsdf sd fsdf

# %%
with open(r'C:\Users\v099452\Sample.txt', 'r+') as testwritefile:
    testwritefile.seek(0,0) #write at beginning of file
    testwritefile.write("Line 1" + "\n")
    testwritefile.write("Line 2" + "\n")
    testwritefile.write("Line 3" + "\n")
    testwritefile.write("Line 4" + "\n")
    testwritefile.write("finished\n")
    testwritefile.seek(0,0)
    print(testwritefile.read())
# Out:
# Line 1
# Line 2
# Line 3
# Line 4
# finished
# f sd fsdf sd fsdf
#
# 333 sdf sdf sd fsdf sd fsdf
#
#
#
#
#
# 444 sdf sdf sd fsdf sd fsdf
#
# 555 sdf sdf sd fsdf sd fsdf

# %%
with open(r'C:\Users\v099452\Sample.txt', 'r+') as testwritefile:
    testwritefile.seek(0,0) #write at beginning of file
    testwritefile.write("Line 1" + "\n")
    testwritefile.write("Line 2" + "\n")
    testwritefile.write("Line 3" + "\n")
    testwritefile.write("Line 4" + "\n")
    testwritefile.write("finished\n")
    testwritefile.truncate()
    testwritefile.seek(0,0)
    print(testwritefile.read())
# Out:
# Line 1
# Line 2
# Line 3
# Line 4
# finished
