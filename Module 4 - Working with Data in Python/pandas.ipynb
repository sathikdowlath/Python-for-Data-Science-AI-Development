# %%
import pandas as pd
path2 = r"‪‪C:\Users\v099452\Data-XLS.xlsx"
clean_path = path2.encode("ascii", "ignore").decode()
df = pd.read_excel(clean_path)
df.head()
#print(set(df['EMPL_ID']))
# Out:
#    BATCH_SEQ_NUMBER  BATCH_ITERATION_SEQ  EMPL_ID START_DATE EXPIRE_DATE  \
# 0                 9                    1     8574 2025-06-29  2026-06-29
# 1                 9                    1     8574 2025-06-29  2026-06-29
# 2                 9                    1     8574 2025-06-29  2026-06-29
# 3                 9                    1     8574 2025-06-29  2026-06-29
# 4                 9                    1     8574 2025-06-29  2026-06-29
#
#   SCHED_TYPE INTERVAL_TYPE  SCHED_DAY          START_TIME            END_TIME  \
# 0       WEEK            SW          1 1990-01-01 07:30:00 1990-01-01 11:30:00
# 1       WEEK            SW          1 1990-01-01 11:30:00 1990-01-01 12:00:00
# 2       WEEK            SW          1 1990-01-01 12:00:00 1990-01-01 16:00:00
# 3       WEEK            SW          2 1990-01-01 07:30:00 1990-01-01 11:30:00
# 4       WEEK            SW          2 1990-01-01 11:30:00 1990-01-01 12:00:00
#
# ...

# %%
 # name of the index using loc 
df.iloc[0,8]
# Out:
# Timestamp('1990-01-01 07:30:00')

# %%
# name of the index using loc 
df.loc[0,'START_TIME']
# Out:
# Timestamp('1990-01-01 07:30:00')

# %%
df1 = df[["SCHED_DAY",'START_DATE']]
df1.head()
# Out:
#    SCHED_DAY START_DATE
# 0          1 2025-06-29
# 1          1 2025-06-29
# 2          1 2025-06-29
# 3          2 2025-06-29
# 4          2 2025-06-29

# %%
dic_object = { "a": ["a","b","c"],"length":[1,2,3]}
dic_object
df = pd.DataFrame(dic_object)
print(df['a'])
print(df['length'])
print(df.head())
# Out:
# 0    a
# 1    b
# 2    c
# Name: a, dtype: object
# 0    1
# 1    2
# 2    3
# Name: length, dtype: int64
#    a  length
# 0  a       1
# 1  b       2
# 2  c       3

# %%
df.iloc[0,0]
# Out:
# 'a'

# %%
df.iloc[0,1]
# Out:
# 1

# %%
df.iloc[1,1]
# Out:
# 2

# %%
df.iloc[2,1]
# Out:
# 3

# %%
songs = { "Album":['Thriller',"back in bblack","Bat out of Hell"],"Release":[1982,1980,1982],"Length":["00:42:19","00:40:00","00:20:00"]}
df = pd.DataFrame(songs)
df.head()
# Out:
#              Album  Release    Length
# 0         Thriller     1982  00:42:19
# 1   back in bblack     1980  00:40:00
# 2  Bat out of Hell     1982  00:20:00

# %%
df['Release']>1981
# Out:
# 0     True
# 1    False
# 2     True
# Name: Release, dtype: bool

# %%
df1=df[df['Release']>1981]
df1
# Out:
#              Album  Release    Length
# 0         Thriller     1982  00:42:19
# 2  Bat out of Hell     1982  00:20:00

# %%
#df1.to_csv('new_df_Release_1981.csv')
df1.to_csv('new_df_Release_1981.csv',index=False)

# %%
path3 = r"‪C:\Users\v099452\Coursera\Python for Data Science, AI & Development\Module 4 - Working with Data in Python\new_df_Release_1981.csv"
clean_path3 = path3.encode("ascii", "ignore").decode()
df3=pd.read_csv(clean_path3)
df3
# Out:
#              Album  Release    Length
# 0         Thriller     1982  00:42:19
# 1  Bat out of Hell     1982  00:20:00

# %%
x = df["Release"]
x = set(x)
x
# Out:
# {1980, 1982}

# %%
print(df["Release"].unique())
# Out:
# [1982 1980]

# %%
df_new = df
df_new.head()
df_new.index=["a","b","c"]
df_new
# Out:
#              Album  Release    Length
# a         Thriller     1982  00:42:19
# b   back in bblack     1980  00:40:00
# c  Bat out of Hell     1982  00:20:00

# %%
df_new.iloc[0,0]
# Out:
# 'Thriller'

# %%
df_new.loc["a","Album"]
# Out:
# 'Thriller'

# %%
z=df_new.iloc[0:2,0:2]
z
# Out:
#             Album  Release
# a        Thriller     1982
# b  back in bblack     1980

# %%
df_new
z=df_new.loc[0:2,'Album':'Release']
z
# Out:
#              Album  Release    Length
# a         Thriller     1982  00:42:19
# b   back in bblack     1980  00:40:00
# c  Bat out of Hell     1982  00:20:00

# %%
import pandas as pd
# Create a Series from a list
data = [10, 20, 30, 40, 50]
s = pd.Series(data)
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
# %pip install xlrd openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pyodide.http import pyfetch
import pandas as pd

filename = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/LXjSAttmoxJfEG6il1Bqfw/Product-sales.csv"

async def download(url, filename):
    response = await pyfetch(url)
    if response.status == 200:
        with open(filename, "wb") as f:
            f.write(await response.bytes())


await download(filename, "Product-sales.csv")
df = pd.read_csv("Product-sales.csv")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from pyodide.http import pyfetch
#       2 import pandas as pd
#       4 filename = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/LXjSAttmoxJfEG6il1Bqfw/Product-sales.csv"
#
# ModuleNotFoundError: No module named 'pyodide'

# %%
import pandas as pd

filename = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/LXjSAttmoxJfEG6il1Bqfw/Product-sales.csv"

df = pd.read_csv(filename)
print(df.head())
# Out:
#    OrderID     Product     Category  Quantity  Price  Total   OrderDate  \
# 0        1      Laptop  Electronics         2    800   1600  2022-01-10
# 1        2  Smartphone  Electronics         3    600   1800  2022-02-15
# 2        3  Desk Chair    Furniture         5    150    750  2022-03-12
# 3        4    Notebook   Stationery        10      2     20  2022-04-05
# 4        5     Monitor  Electronics         1    300    300  2022-05-21
#
#   CustomerCity
# 0     New York
# 1  Los Angeles
# 2      Chicago
# 3      Houston
# 4        Miami
